# %% [markdown]
# # Day 2 – Exploratory Data Analysis with Pandas
#
# ## 📝 Task:
# Use Pandas to explore the Netflix dataset and practice:
# - Data loading
# - Inspection
# - Filtering
# - Cleaning
# - Grouping
# - Visualization (if possible)

# %% [markdown]
# ### 📥 Importing Dataset
#
# 🔍 **What I’m doing:**
# Importing the `pandas` library and loading the Netflix dataset from a CSV file into a DataFrame called `df`.
#
# 🧠 **Why I’m doing it:**
# Pandas makes it easy to load, explore, and manipulate tabular data — which is essential for analysis.
#
# 📊 **What the output means:**
# This displays the full dataset as a DataFrame, giving us a first look at all the columns and rows available for analysis.

# %%
#Importing Pandas
import pandas as pd

# %%
#loding Netflix data set (CSV File)
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Printing first 5 records
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Printing last 5 records
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# Size of data (count of rows & columns)
col , row = df.shape
print("column count:", col)
print("Row count:", row)
# Out:
# column count: 8807
# Row count: 12

# %%
# Column information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Handling Missing Values

# Filling String -based missing values
df["director"] = df["director"].fillna("Unknown")
df["cast"] = df["cast"].fillna("Not Listed")
df["country"] = df["country"].fillna("Unknown")
df["rating"] = df["rating"].fillna("Unrated")
df["duration"] = df["duration"].fillna("Unknown")

# dropping missing rows from 'date_added' (only 10 rows)
df.dropna(subset="date_added",inplace=True)

# %%
# After Handling Missing Values
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                         Not Listed  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                         Not Listed        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Displaying Movies from "India"
df[(df['country']=='India') & (df['type'] == 'Movie')]
# Out:
#      show_id   type                  title                 director  \
# 24       s25  Movie                  Jeans               S. Shankar
# 105     s106  Movie       Angamaly Diaries     Lijo Jose Pellissery
# 114     s115  Movie                 Anjaam             Rahul Rawail
# 116     s117  Movie                 Dhanak          Nagesh Kukunoor
# 118     s119  Movie                Gurgaon            Shanker Raman
# ...      ...    ...                    ...                      ...
# 8772   s8773  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 8773   s8774  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 8798   s8799  Movie               Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800  Movie                  Zenda           Avadhoot Gupte
# 8806   s8807  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %%
# Displaying shows rated "TV-MA"
df[(df['type']=='TV Show') & (df['rating'] == 'TV-MA')]
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8609   s8610  TV Show                 Towies          Unknown
# 8633   s8634  TV Show                Trotsky          Unknown
# 8700   s8701  TV Show      Wartime Portraits          Unknown
# 8710   s8711  TV Show                  Weeds          Unknown
# 8749   s8750  TV Show             Winter Sun          Unknown
#
#                                                    cast        country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# ...

# %%
# Displaying titels releaseed after 2015
df[df['release_year'] > 2015]
# Out:
#      show_id     type                      title         director  \
# 0         s1    Movie       Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show              Blood & Water          Unknown
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans          Unknown
# 4         s5  TV Show               Kota Factory          Unknown
# ...      ...      ...                        ...              ...
# 8787   s8788    Movie  You Can’t Fight Christmas      Kenny Young
# 8794   s8795    Movie                     اشتباك     Mohamed Diab
# 8796   s8797  TV Show                 Yunus Emre          Unknown
# 8797   s8798  TV Show                  Zak Storm          Unknown
# 8803   s8804  TV Show                Zombie Dumb          Unknown
#
#                                                    cast  \
# 0                                            Not Listed
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
# sorting data by title and release_year
df.sort_values(by = ['title','release_year'], inplace=True )
df
# Out:
#      show_id     type                          title  \
# 2036   s2037    Movie                         #Alive
# 2304   s2305    Movie  #AnneFrank - Parallel Stories
# 2481   s2482    Movie              #FriendButMarried
# 2324   s2325    Movie            #FriendButMarried 2
# 5973   s5974    Movie                          #Roxy
# ...      ...      ...                            ...
# 6177   s6178  TV Show                       忍者ハットリくん
# 4914   s4915  TV Show                           海的儿子
# 7101   s7102  TV Show                           마녀사냥
# 5022   s5023    Movie                        반드시 잡는다
# 7108   s7109    Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 2036                       Cho Il
# 2304  Sabina Fedeli, Anna Migotto
# 2481                Rako Prijanto
# 2324                Rako Prijanto
# 5973              Michael Kennedy
# ...                           ...
# 6177                      Unknown
# 4914                      Unknown
# ...

# %%
#  Group by type
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2666
# Name: count, dtype: int64

# %%
# Group by Country
df['country'].value_counts()
# Out:
# country
# United States                                                   2812
# India                                                            972
# Unknown                                                          830
# United Kingdom                                                   418
# Japan                                                            244
#                                                                 ...
# Hong Kong, China, Singapore                                        1
# South Africa, China, United States                                 1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Italy, Turkey                                                      1
# Egypt, Austria, United States                                      1
# Name: count, Length: 749, dtype: int64

# %%
# bar plot for types
import matplotlib.pyplot as plt

df['type'].value_counts().plot(kind='bar', color=['#1f77b4', '#ff7f0e'])
plt.title('Count of Movies vs TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()
